# %% [markdown]
# # GUESS GAME

# %%
import random

# %%
random.randint(1,23)
# Out:
# 16

# %%
jackpot = random.randint(1,10)
guess = int(input("ENTER YOUR GUESS"))
counter = 1 

while guess != jackpot:
    if guess < jackpot:
        print("guess higher")
    else:
        print("guess lower")
    guess =  int(input("guess again"))
    counter +=1 

print("YO BRO YOU ARE RIGHT")
print(f"you took {counter} attempts")
# Out:
# guess higher
# guess higher
# guess higher
# guess higher
# YO BRO YOU ARE RIGHT
# you took 5 attempts

# %%
# import random

# jackpot = random.randint(1, 10)
# guess = int(input("ENTER YOUR GUESS: "))

# while guess != jackpot:
#     if guess < jackpot:
#         print("Guess Higher")
#     else:
#         print("Guess Lower")

#     guess = int(input("Guess Again: "))

# print("YO BRO YOU ARE RIGHT")
# Out:
# Guess Higher
